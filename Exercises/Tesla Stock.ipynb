# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
API_KEY = 'wa-FxFLJyWvFsyxj6zpA'

# %%
from pandas_datareader import data as web
import datetime

# %%
start = datetime.datetime(2017, 1, 1)
end = datetime.datetime(2020, 1, 1)

tesla = web.DataReader('TSLA', 'quandl', start, end, api_key=API_KEY)

# %%
tesla.head()
# Out:
#               Open    High     Low   Close      Volume  ExDividend  \
# Date
# 2018-03-27  304.00  304.27  277.18  279.18  13696168.0         0.0
# 2018-03-26  307.34  307.59  291.36  304.18   8324639.0         0.0
# 2018-03-23  311.25  311.61  300.45  301.54   6600538.0         0.0
# 2018-03-22  313.89  318.82  308.18  309.10   4914307.0         0.0
# 2018-03-21  310.25  322.44  310.19  316.53   5927881.0         0.0
#
#             SplitRatio  AdjOpen  AdjHigh  AdjLow  AdjClose   AdjVolume
# Date
# 2018-03-27         1.0   304.00   304.27  277.18    279.18  13696168.0
# 2018-03-26         1.0   307.34   307.59  291.36    304.18   8324639.0
# 2018-03-23         1.0   311.25   311.61  300.45    301.54   6600538.0
# 2018-03-22         1.0   313.89   318.82  308.18    309.10   4914307.0
# 2018-03-21         1.0   310.25   322.44  310.19    316.53   5927881.0

# %%
tesla.to_csv('../data/Tesla_Stock.csv')

# %%
ford = web.DataReader('F', 'quandl', start, end, api_key=API_KEY)
gm = web.DataReader('GM', 'quandl', start, end, api_key=API_KEY)

# %%
ford.head()
# Out:
#              Open    High    Low  Close      Volume  ExDividend  SplitRatio  \
# Date
# 2018-03-27  10.85  10.920  10.72  10.83  38263798.0         0.0         1.0
# 2018-03-26  10.74  10.870  10.68  10.83  52165572.0         0.0         1.0
# 2018-03-23  10.79  10.850  10.51  10.56  39706214.0         0.0         1.0
# 2018-03-22  11.00  11.060  10.73  10.75  50907549.0         0.0         1.0
# 2018-03-21  11.00  11.185  10.93  11.10  38407514.0         0.0         1.0
#
#             AdjOpen  AdjHigh  AdjLow  AdjClose   AdjVolume
# Date
# 2018-03-27    10.85   10.920   10.72     10.83  38263798.0
# 2018-03-26    10.74   10.870   10.68     10.83  52165572.0
# 2018-03-23    10.79   10.850   10.51     10.56  39706214.0
# 2018-03-22    11.00   11.060   10.73     10.75  50907549.0
# 2018-03-21    11.00   11.185   10.93     11.10  38407514.0

# %%
gm.head()
# Out:
#              Open   High     Low  Close      Volume  ExDividend  SplitRatio  \
# Date
# 2018-03-27  36.02  36.03  34.500  34.87  17393191.0         0.0         1.0
# 2018-03-26  35.94  36.05  35.285  35.99   9251162.0         0.0         1.0
# 2018-03-23  36.42  36.59  35.130  35.17  12939065.0         0.0         1.0
# 2018-03-22  37.23  37.33  36.270  36.35  12455805.0         0.0         1.0
# 2018-03-21  37.16  38.02  37.100  37.58  11412099.0         0.0         1.0
#
#             AdjOpen  AdjHigh  AdjLow  AdjClose   AdjVolume
# Date
# 2018-03-27    36.02    36.03  34.500     34.87  17393191.0
# 2018-03-26    35.94    36.05  35.285     35.99   9251162.0
# 2018-03-23    36.42    36.59  35.130     35.17  12939065.0
# 2018-03-22    37.23    37.33  36.270     36.35  12455805.0
# 2018-03-21    37.16    38.02  37.100     37.58  11412099.0

# %%
ford.to_csv('../data/Ford_Stock.csv')
gm.to_csv('../data/GM_Stock.csv')

# %% [markdown]
# ### Visualizing the Data

# %%
tesla['Open'].plot(label='Tesla',figsize=(16,8),title='Open Price')
ford['Open'].plot(label='GM')
gm['Open'].plot(label='GM')
plt.legend()

# %%
tesla['Volume'].plot(label='Tesla', figsize=(16,8),title='Volume Traded')
ford['Volume'].plot(label='Ford')
gm['Volume'].plot(label='GM')
plt.legend()

# %%
ford['Volume'].argmax()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
#   """Entry point for launching an IPython kernel.
# Timestamp('2018-01-17 00:00:00')

# %%
tesla['Total Traded'] = tesla['Open']*tesla['Volume']
ford['Total Traded'] = ford['Open']*ford['Volume']
gm['Total Traded'] = gm['Open']*gm['Volume']

# %%
tesla['Total Traded'].plot(label='Tesla',figsize=(16,8))
gm['Total Traded'].plot(label='GM')
ford['Total Traded'].plot(label='Ford')
plt.legend()
plt.ylabel('Total Traded')
# Out:
# Text(0, 0.5, 'Total Traded')

# %%
tesla['Total Traded'].argmax()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
#   """Entry point for launching an IPython kernel.
# Timestamp('2017-06-09 00:00:00')
